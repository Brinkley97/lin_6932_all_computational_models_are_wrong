# %% [markdown]
# ## Some Basic Probabilistic Distribution & N-gram Probabilities
#
#
# Zoey Liu
#
# (Partial credits to Richard Futrell.)
#
# For those that decide to use Goolge Colab: Google Colab, in a lot of ways, is similar to Jupyter Notebook. It allows us to have more flexibility with storage, coding interface, and access to computing resources (e.g., GPU). Most importantly, it is FREE! In this coding session, we will familiarize ourselves with Colab via some (not so new) practices with implementing some basic probabilistic distribution and calculating N-gram probabilities.

# %% [markdown]
# ### Getting started with probabilities

# %% [markdown]
# As discussed in class, when it comes to calculation of probabilities, we turn to using logarithmic forms to avoid underflow problems.

# %%
import math

digit = '4'
digit = int(digit)
print(math.log(digit, 2))
# Out:
# 2.0

# %% [markdown]
# Now say I have a list of numbers, and I want to calculate the sum of the log (base 2) of each number given a list.

# %%
list_1 = [1, 2, 3, 4, 5, 6]

### Insert your code here ###
log_nums = []
for i in list_1:
    digit = int(i)
    log_num = math.log(i, 2)
    log_nums.append(log_num)

print(log_nums)
print(sum(log_nums))
# Out:
# [0.0, 1.0, 1.5849625007211563, 2.0, 2.321928094887362, 2.584962500721156]
# 9.491853096329674

# %% [markdown]
# Now I have new list; and I want to calculate the sum of the log (base 2) of each number given the list, again

# %%
list_2 = [100, 200, 300, 400, 500, 600]

### Insert your code here ###
log_nums = []
for i in list_2:
    digit = int(i)
    log_num = math.log(i, 2)
    log_nums.append(log_num)

print(log_nums)
print(sum(log_nums))
# Out:
# [6.643856189774725, 7.643856189774724, 8.228818690495881, 8.643856189774725, 8.965784284662087, 9.228818690495881]
# 49.354990234978025

# %% [markdown]
# How about when I have six lists?

# %%
all_lists = [[1, 2, 3, 4, 5, 6], [100, 200, 300, 400, 500, 600], [1.5, 3, 4.2, 5.8], [90, 45], [0.4, 0.8, 0.3], [10000]]

### Insert your code here ###

global_log_nums = []
for i in range(len(all_lists)):
    local_log_nums = []
    sub_list = all_lists[i]
    print(sub_list)
    for j in range(len(sub_list)):
        # print(f"List: {i}\n Number: {j}")
        num = sub_list[j]
        # print(num)
        digit = int(num)
        log_num = math.log(num, 2)
        local_log_nums.append(log_num)
        print(f"List {i} | Number: {num} -> log({num}) = {log_num}")
    log_nums_total = sum(local_log_nums)
    print(f"Local Sum (for list {i}): {log_nums_total}")
    global_log_nums.append(log_nums_total)
    # print(f"List: {i}\n Number: {j}")
    # print(global_log_nums)
    print()
global_nums_total = sum(global_log_nums)
print(f"Global Sum: {global_nums_total}")
# Out:
# [1, 2, 3, 4, 5, 6]
# List 0 | Number: 1 -> log(1) = 0.0
# List 0 | Number: 2 -> log(2) = 1.0
# List 0 | Number: 3 -> log(3) = 1.5849625007211563
# List 0 | Number: 4 -> log(4) = 2.0
# List 0 | Number: 5 -> log(5) = 2.321928094887362
# List 0 | Number: 6 -> log(6) = 2.584962500721156
# Local Sum (for list 0): 9.491853096329674
#
# [100, 200, 300, 400, 500, 600]
# List 1 | Number: 100 -> log(100) = 6.643856189774725
# List 1 | Number: 200 -> log(200) = 7.643856189774724
# List 1 | Number: 300 -> log(300) = 8.228818690495881
# List 1 | Number: 400 -> log(400) = 8.643856189774725
# List 1 | Number: 500 -> log(500) = 8.965784284662087
# List 1 | Number: 600 -> log(600) = 9.228818690495881
# Local Sum (for list 1): 49.354990234978025
#
# [1.5, 3, 4.2, 5.8]
# List 2 | Number: 1.5 -> log(1.5) = 0.5849625007211562
# List 2 | Number: 3 -> log(3) = 1.5849625007211563
# List 2 | Number: 4.2 -> log(4.2) = 2.070389327891398
# List 2 | Number: 5.8 -> log(5.8) = 2.5360529002402097
# ...

# %% [markdown]
# In practice, for both efficiency and aesthetics, a lot of times we can use a function to replace some of the code above. Below I have defined a function named. ```computation```. What does this function do? How can I modify this function to calculate the sum of the log of each number for every list in variable ```all_lists```?

# %%
def computation(variable):
  value = math.log(variable, 2)
  return value

### Insert your code here ###
def computation(variable):
  if type(variable) == int:
    value = math.log(variable, 2)
    return value
  elif type(variable) == list:
    global_log_nums = []
    for i in range(len(all_lists)):
        local_log_nums = []
        sub_list = all_lists[i]
        print(sub_list)
        for j in range(len(sub_list)):
            # print(f"List: {i}\n Number: {j}")
            num = sub_list[j]
            # print(num)
            digit = int(num)
            log_num = math.log(num, 2)
            local_log_nums.append(log_num)
            print(f"List {i} | Number: {num} -> log({num}) = {log_num}")
        log_nums_total = sum(local_log_nums)
        print(f"Local Sum (for list {i}): {log_nums_total}")
        global_log_nums.append(log_nums_total)
        # print(f"List: {i}\n Number: {j}")
        # print(global_log_nums)
        print()
    global_nums_total = sum(global_log_nums)
    print(f"Global Sum: {global_nums_total}")

# computation(4)
computation(all_lists)
# Out:
# [1, 2, 3, 4, 5, 6]
# List 0 | Number: 1 -> log(1) = 0.0
# List 0 | Number: 2 -> log(2) = 1.0
# List 0 | Number: 3 -> log(3) = 1.5849625007211563
# List 0 | Number: 4 -> log(4) = 2.0
# List 0 | Number: 5 -> log(5) = 2.321928094887362
# List 0 | Number: 6 -> log(6) = 2.584962500721156
# Local Sum (for list 0): 9.491853096329674
#
# [100, 200, 300, 400, 500, 600]
# List 1 | Number: 100 -> log(100) = 6.643856189774725
# List 1 | Number: 200 -> log(200) = 7.643856189774724
# List 1 | Number: 300 -> log(300) = 8.228818690495881
# List 1 | Number: 400 -> log(400) = 8.643856189774725
# List 1 | Number: 500 -> log(500) = 8.965784284662087
# List 1 | Number: 600 -> log(600) = 9.228818690495881
# Local Sum (for list 1): 49.354990234978025
#
# [1.5, 3, 4.2, 5.8]
# List 2 | Number: 1.5 -> log(1.5) = 0.5849625007211562
# List 2 | Number: 3 -> log(3) = 1.5849625007211563
# List 2 | Number: 4.2 -> log(4.2) = 2.070389327891398
# List 2 | Number: 5.8 -> log(5.8) = 2.5360529002402097
# ...

# %% [markdown]
# ### Some basic probability distributions
#
# Last week, we have talked about some basic probabilistic distributions. Let's take a look at some simple implementations.
#
# First, let's define a variable named ```OUTCOMES``` to capture the possible outcomes of a fair coin flip.

# %%
### Insert your code here ###
OUTCOMES = ['heads', 'tails']

# %% [markdown]
# Now, define a function ```fair_coin_flip``` that returns the random outcome of a fair coin flip. What probability distribution does this function define?
#
# ***Hint***: use the ```random.choice``` function from the Python library ```random```. Pay attention to the type of the output given by ```random.choice```

# %%
### Insert your code here ###
import random


def fair_coin_flip(outcomes):
    return random.choice(outcomes)

fair_coin_flip(OUTCOMES)
# Out:
# 'heads'

# %% [markdown]
# What outcome do you get when flipping the fair coin once? What outcomes do you get when flipping the fair coin 10 times, 1000 times, 10000 times?
#
# How many T do you get when flipping the fair coin 10000 times? (Some code takes a while to run; be patient)
#
# What kind of distribution do you get when flipping the fair coin more than once?

# %%
### Insert your code here
flips = 10000

heads = []
tails = []

for flip in range(flips):
    outcome = fair_coin_flip(OUTCOMES)
    if outcome == "heads":
        heads.append(flip)
    elif outcome == "tails":
        tails.append(flip)

heads_count = len(heads)
tails_count = len(tails)
print(heads_count, tails_count)

heads_distribution = heads_count / flips
tails_distribution = tails_count / flips

heads_distribution, tails_distribution
# Out:
# 5051 4949
# (0.5051, 0.4949)

# %% [markdown]
# Now we move on to a less fair coin. Say everytime I flip this coin, the probability of me getting H is 0.6. What is the probability of me getting T?
#
# Define a function named ```coin_flip``` that will return the outcome of flipping a coin once with its corresponding probility as noted above.
#
# ***Hint***: use the ```weights``` parameter within the ```random.choice``` function.

# %%
### Insert your code here
def coin_flip(outcomes):
    return random.choices(outcomes, weights=[0.6, 0.4])

coin_flip(OUTCOMES)
# Out:
# ['heads']

# %% [markdown]
# What outcome do you get when flipping the fair coin once? What outcomes do you get when flipping the fair coin 10 times, 1000 times, 10000 times?
#
# How many T do you get when flipping the fair coin 10000 times? (Some code takes a while to run; be patient)
#
# What kind of distribution do you get when flipping the fair coin more than once?

# %% [markdown]
# Could you write similar code for defining the multinomial distribution?

# %%
### Insert your code here

# %% [markdown]
# ### True probabilities vs empirical probabilities

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Say I'm back to rolling the dice. The true probabilities of rolling each of 1, 2, 3, ..., 6 are stored in the variable `dice_probability`.

# %%
dice_probability = np.array([.3, .2, .1, .2, .15, .05])
print(dice_probability)
print(dice_probability[0]) # the probability to roll 1
print(dice_probability[1]) # the probability to roll 2, etc.
# Out:
# [0.3  0.2  0.1  0.2  0.15 0.05]
# 0.3
# 0.2

# %%
# Visualize the probability distribution as a bar plot
# It is also useful to visualize the distribution
def plot_dice_probability(p):
  x = np.arange(6) + 1
  plt.bar(x, p)
  plt.xlabel("Outcome x")
  plt.ylabel("Probability p(x)")

plot_dice_probability(dice_probability)

# %%
# We can simulate random dice rolls in this way
x = np.arange(6) + 1 # why +1?
print(np.random.choice(x, p=dice_probability)) # Simultating one random dice roll
# Out:
# 4

# %%
# Let's simulate 100 dice rolls:
N = 100
sample = np.random.choice(x, p=dice_probability, size=N)
sample
# Out:
# array([1, 1, 1, 4, 2, 1, 5, 4, 3, 1, 1, 5, 5, 1, 5, 5, 2, 5, 3, 2, 2, 2,
#        5, 2, 3, 5, 1, 4, 4, 4, 4, 1, 4, 4, 3, 5, 2, 2, 6, 2, 2, 1, 1, 2,
#        6, 4, 4, 5, 5, 1, 1, 3, 1, 1, 1, 4, 5, 5, 4, 3, 5, 6, 2, 1, 2, 1,
#        4, 4, 2, 3, 1, 6, 1, 4, 6, 1, 1, 3, 1, 4, 1, 3, 1, 4, 5, 6, 5, 4,
#        3, 1, 5, 6, 1, 2, 5, 6, 2, 1, 4, 1])

# %%
# Now we can compute the empirical frequencies of the outcomes in the sample
from collections import Counter
sample_frequency = np.zeros(6)
for outcome in sample:
  sample_frequency[outcome-1] += 1 # why -1?
sample_frequency
# Out:
# array([29., 16., 10., 19., 18.,  8.])

# %%
# And compare these to the underlying probabilities that were used to generate the data.
def double_bar(x, y1, y2, width=0.4):
  plt.bar(x-width/2, y1, width)
  plt.bar(x+width/2, y2, width)

N = 1000

double_bar(x, dice_probability, sample_frequency/N)
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.legend(["True probability", "Sample frequency"])

# %% [markdown]
# What does this tell you about the difference between probability and sample frequency? What happens when you increase the sample size $N$?
#
# > This tells us the difference between probability and sample frequency are inverse. Increasing N leads to an increase in true probability and decrease in sample frequency.

# %% [markdown]
# ### A simple generator

# %% [markdown]
# When discussing probability, we talked about solving problems with probability. One type of problems is ***generation and prediction***. For instance, Just learning the probability of getting H or T isn't always terribly interesting. In cognitive modeling (and many other aspects of NLP), we are interested in what these probabilities can guide our comprehension, production, learning, and online prediction.
#
# Here we will demonstrate the idea of generation with a simple example. Let's say I'm trying to produce some sequence of symbols based on the results of rolling a fair die. If I get 1 or 2, this generates the symbol 'this', if I get 3 or 4, this generates the symbo 'is', otherwise we get the symbol 'wug'. I roll this die to generate a sequence of 8 symbols. How many possible sequence could I have? Could you write a function that defines a generator that will generate ***one*** possible 8-symbol sequence randomly?
#
# > 8! possible sequences

# %%
### Insert your code here ###

def generator():
  sequence = []
  for i in range (8):
    outcome = random.choices([1,2,3,4,5,6], weights = [1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
    if outcome[0] in [1,2]:
      sequence.append('this')
    elif outcome[0] in [3, 4]:
      sequence.append('is')
    elif outcome[0] in [5, 6]:
      sequence.append('wug')
  return sequence

generator()
# Out:
# ['this', 'is', 'wug', 'wug', 'is', 'wug', 'wug', 'wug']

# %% [markdown]
# ### Bayesian inference for Speech Categorization
#
# ## Setting up the question
#
# Let's say we are trying to distinguish/categorize two sounds, /b/ and /p/, based on their voice onset time (VOT) (what are some of the assumptions we are making here)?
#
# From Bayesian inversion equation, we know that we can write the following equation, using *S* as the variable for sound category, and *VOT* as the variable for acoustic signal/representation (VOT in this case):
#
# $P(S | VOT) = \frac{P(VOT | S)P(S)}{P(VOT)}$

# %% [markdown]
# From the literature, we learned that the distributions of VOT for /b/ and /p/ roughly look like this, and that the variance of VOT for /p/ is larger than that for /b/:
#
# ![Screenshot 2023-09-01 at 3.08.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# **Question**: do you think we could also get the probability distributions above from speech corpora as well? Do you think we will be able to get reliable estimates?
#
# > Yes and yes, if we set up the study how Chen did. Also, I assume langage has changed since then, so even if we try to replicate/reproduce Chen's study, we'd get slighly different results.

# %% [markdown]
# These plots indicate that the distribution of speech cues (e.g., VOT) is probabilistic. With Bayesian inference, we can investigate questions such as "Do listeners perceive speech following probabilistic acoustic cues?", or "Are listeners sensitive to probabilistic information of acoustic cues"?
#
# For those that are interested, please see [this article](https://pdf.sciencedirectassets.com/271061/1-s2.0-S0010027708X00083/1-s2.0-S0010027708001017/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjECsaCXVzLWVhc3QtMSJHMEUCIGqyhJAkM7adUWGzHByxeUReVCohGMlGoTPnZ%2Baj%2ByACAiEA%2F%2BUBlgIvJFAiUXaCSrHJe4EWEsptpm5HQidIM4PVx%2BQqvAUI8%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAFGgwwNTkwMDM1NDY4NjUiDMjoW4Q35ejF6hhXKSqQBfbAUnqyeeqkAlCn7R21%2FA6QtpKCYg2DN%2FUPs8c8KwifV%2FdD7WROq8Xz7PPyTK8Abs6C225AhZywtpjI%2B%2FIO9LoDWWV%2FvF35Q1LP5eiGCLWjkfmjV2eF35YJmLoTQftsXBGfLlxW3M7pgee2BQNJb6LZuaZVt%2FBxsIeKIc6BG9t05KPPL0nx529Z0zv4FmeVLUVF2JorLE9WT0qxqG2Av%2FyJaBbKZ%2FBGg6Q5CHsZ2l9bYRhTGqnybPUdCVITlPD0CAY9BvLqYfIZ1qQNZPL8nw6Ohzdm6LNRNv8g7y2%2FHsDXNfMpOL0Ipn4lXwYqmz25ZE7CH9dNwoXjI64t13J3Jai50JUX6CQLPe%2F%2BYzVPhyKxMzz%2FzzN%2FOyYudBqX%2BFNotc0KeNKtGTNovCpz6Gi7tgz%2Bor9tpPsDihqeiQW1PFQlmQrHExFGRndLwmZ5sOfTifXrdhBLwltahT0FvRX4uPtqztr5rfWX%2FMR%2FQlsxhFOJ5NttPVKnldHyUYIYkHfWLa0UNzXtirFzEI6QhNt6inJWdLMg3yNCGqmx4FgdCatVp4pRdWHY%2Fa5kL6IziHZor%2Fc8NkEJHPFX8eQbGfwmn7XJCSCOf02NIQyyWc3L55DO9p6tbUcYHbCXOwWM4Zh%2F6MG1cYBc8I95b7gLhhTgicoaiyvHEHH6Rr33FaH5X6gzzg338f5Mu5lgGwSmCIEs0Z0zWdec65C13VaGWfu8ewKhpbkBOP3tjUZcnjlB7tSoQSSswJR0B68%2FPICsKeowrie5UdJVnGcNuiPrzR2smub6QaAokz0KWGZ7Sz6EYspqYoj7tYMUG%2Fdl9y6E9uS5DMiz93SVcbYyXgrvTy7jclmakrhVhw2l3c0ghL%2BuIVsnMKHTyKcGOrEBMBseHFfHRE5jXyDI5wey%2B08OWMeQI95Ovg2TlM9hzsBs7pkMHt1SvpXm7vwJ2bTb1hmyv9E2u7XKhvjhoGHHHboVjstHNkObShzWAkSP5H9JSGfiVYSeVwncefr7lqYcWTNUvncOda2XR2yuMCqNOkup7jKvfxNT6QxGV9rcIozi481kNcYoVNqwqFs5w7JVVbbPp%2Bv1wnFiX1eg0wi0qYbMmJEJ9V2LjkfwZTJUnptF&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230901T191028Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYQY3G34U4%2F20230901%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=c41530145568b75f707016995246467f47c391825aa900d3dc702144a5d53005&hash=b77838605ca0818fb20b59c8398775317d20b4e61038e3cfc90be82b8a8590d9&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S0010027708001017&tid=spdf-90a118a4-f569-4da9-9751-5aee35c6ca10&sid=4b37a7b58be7804674680393be8598cb835dgxrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=0f10540700090a545051&rr=7fffd043bef59ad2&cc=us) as a good starting point.
#
# **Note**: Cross-linguistic work is encouraged.

# %% [markdown]
# ## Calculating the likelihood
#
# From class, and the plot above, we see that the distribution of VOT for /b/ or /p/ can be approximated as a normal distribution. The probability density function of normal distribution is as follows:
#
# ![Screenshot 2023-09-01 at 3.21.40 PM.png](data:image/png;base64,...)
#
# With this equation, we can calculate the likelihood, $P(VOT | S)$.

# %% [markdown]
# **Question:** Suppose I hear a sound with VOT of 27ms. Which sound category does it belong to?
#
# > /b/
#
# To address the question above, we need to find a normal distribution that *looks like* the one in the plot above; in other words, the shape of the normal distribution has to approximate the one above. Note that the shape of a normal distribution depends on the mean $\mu$ and the standard deviation $\sigma$. So let's try looking at normal distributions with different values for $\mu$ and $\sigma$.

# %%
import numpy as np

# %%
mu, sigma = 100, 20

# %%
s = np.random.normal(mu, sigma, 1000)
s
# Out:
# array([114.49471893, 103.0155658 , 138.68791809, 123.43994575,
#         84.53008917,  92.6305143 ,  96.21471591,  97.37651688,
#         95.0162691 ,  92.3555716 ,  97.0711464 ,  89.98743699,
#        106.75195978,  90.82049575,  86.55252878,  86.62991938,
#        116.59513874,  68.08160933, 102.49114787,  91.11441197,
#         93.44345755, 101.16657371, 102.17212752,  78.50157189,
#         89.90916127,  92.43457114,  84.19639454, 112.52712247,
#        117.33050854,  87.03566509, 102.67733798,  90.26800676,
#        115.85628177, 105.00154045, 116.99825845,  98.53027312,
#        103.2268888 ,  94.69195489,  77.94040047, 107.26334781,
#         87.8880082 , 112.88046992,  95.88894072, 124.74545782,
#         91.66109535,  90.46122461, 122.44198132, 108.62727685,
#        103.62083027, 128.55618199,  66.35711095, 124.20705885,
#         95.59339221, 107.39324169, 115.99293604,  90.00422329,
#         82.1642346 , 135.31260625,  67.40096454,  71.57618057,
# ...

# %%
## Checking the shape of our distribution
abs(mu - np.mean(s))
# Out:
# np.float64(0.21429094169550922)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(s, hist=False, kde=True, color = 'darkblue')
# Out:
# /var/folders/78/9z0b45fx1xqbwxh8vk97lcfh0000gn/T/ipykernel_17794/3321684068.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(s, hist=False, kde=True, color = 'darkblue')
# <Axes: ylabel='Density'>

# %% [markdown]
# After getting a reasonable value of $\sigma$ for the distribution of VOT for /b/ (which is?), we can calculate the likelihood $P(VOT = 27|/b/)$.
#
# ![Screenshot 2023-09-01 at 3.21.40 PM.png](data:image/png;base64,...)

# %%
## Calculating the likelihood when VOT = 27ms
import math

likelihood = (1 / math.sqrt(2*math.pi*sigma)) * math.exp(-(((27 - mu)^2) / (2*sigma^2)))
print(likelihood)
# Out:
# 0.532011387780374

# %% [markdown]
# Now show your work for calculating the likelihood $P(VOT = 27|/p/)$.

# %%
## Insert code here
## You can repeat some of the code above, of course
likelihood = (1 / math.sqrt(2*math.pi*sigma)) * math.exp(-(((27 - mu)^2) / (2*sigma^2)))
print(likelihood)
# Out:
# 0.532011387780374

# %% [markdown]
# ## *Calculating* the Prior and the Posterior
#
# In class, we discussed that we can esimate the prior of a certain sound category from corpus. But what if we don't have a corpus of this sort?
#
# In a way, we can think of *prior* as the probability of a variable before learning further information (think about the literal meaning of the word "prior"). For instance, in this case we can think of $P(/b/)$ as the probability of the sound /b/ before learning ANYTHING about its acoustic representations/cudes. What might $P(/b/)$ be?

# %%
## Set the prior probability for P(/b/)
## Insert your code here
p_b = .5

# %% [markdown]
# Now think about how you would calculate the posterior $P(/b/ | VOT)$ for **a series of VOT values**. Please take some time to check the code cells below for correctness and understand what they do.

# %%
## Insert your code here
list_vot_values = list(np.arange(0, 100, 1))

# %%
def likelihood_function(mu, sigma, VOT):
  likelihood = 1 / ((2 * math.pi * sigma ** 2) ** 0.5) * math.e ** (-1 * (VOT - mu) ** 2 / (2 * sigma ** 2))
  return likelihood

# %%
posterior_values = []
for vot_value in list_vot_values:
  numerator = likelihood_function(30, 8, vot_value) * 0.75
  denominator = likelihood_function(30, 8, vot_value) * 0.75 + likelihood_function(100, 12, vot_value) * 0.25
  posterior = numerator / denominator
  posterior_values.append(posterior)

# %%
sns.lineplot(x = list_vot_values, y = posterior_values)
# Out:
# <Axes: >

# %% [markdown]
# **Question:** So what do you think the posterior distribution for /p/ should look like?
#
# > Since I assigned a .5 for /b/, I'd say the same if I assign .5 for /p/

# %% [markdown]
# ### N-gram probabilities
#
# Word-based Language models in some way can be seen as means of modeling human syntactic knowledge, or modeling some proxy of syntax. Here we will calculate some N-gram probabilities, again with the ```nltk``` package.

# %%
# You might need to install nltk
# pip install nltk

# %%
import nltk
#We choose the gutenberg corpus ...
nltk.download('gutenberg')
nltk.download('punkt')

#...and have a look, which texts are contained in it
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/detraviousjamaribrinkley/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/detraviousjamaribrinkley/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
#We shortcut to gutenberg to keep sequences shorter
from nltk.corpus import gutenberg

caesar = gutenberg.words('shakespeare-caesar.txt') #creates a list of words from the text
print(caesar[:20])
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', 'by', 'William', 'Shakespeare', '1599', ']', 'Actus', 'Primus', '.', 'Scoena', 'Prima', '.', 'Enter', 'Flauius', ',']

# %%
from nltk import bigrams #here we demonstrate bigrams

first_sentence = gutenberg.sents('shakespeare-caesar.txt')[5] #our first example are the first 5 sentences of Julius Caesar
print(first_sentence)
# Out:
# ['Hence', ':', 'home', 'you', 'idle', 'Creatures', ',', 'get', 'you', 'home', ':', 'Is', 'this', 'a', 'Holiday', '?']

# %% [markdown]
# Now let's create some bigrams with ```first_sentence```. What does the ```pad``` parameter do in the ```bigrams``` function?
#
# > `pad` adds "None" to the beginning (left) and end (right) of the sentence

# %%
print(list(bigrams(first_sentence, pad_left=True, pad_right=True)))
# Out:
# [(None, 'Hence'), ('Hence', ':'), (':', 'home'), ('home', 'you'), ('you', 'idle'), ('idle', 'Creatures'), ('Creatures', ','), (',', 'get'), ('get', 'you'), ('you', 'home'), ('home', ':'), (':', 'Is'), ('Is', 'this'), ('this', 'a'), ('a', 'Holiday'), ('Holiday', '?'), ('?', None)]

# %% [markdown]
# Now we move on to getting bigrams from the full corpus. We will store the bigram counts in a python dictionary

# %%
from collections import defaultdict #we need the defaultdictionary library for counting bigrams in the box below
model = defaultdict(lambda: defaultdict(lambda: 0))
print(model)
# Out:
# defaultdict(<function <lambda> at 0x1196abf60>, {})

# %%
for sentence in gutenberg.sents('shakespeare-caesar.txt'): #for all sentences
    #words should be lowercase (lower()), remove all punctuation (isalpha())
    words = [word.lower() for word in sentence if word.isalpha()]

    for w1, w2 in bigrams(words, pad_right=True, pad_left=True): #now we count bigrams according to their occurrence
        model[w1][w2] += 1

# %% [markdown]
# Now try calculating the bigram probability of "you idle" and "get you" with Maximum likelihood estimation.
#
# > Using documentation here: https://www.nltk.org/api/nltk.lm.html

# %%
### Insert your code here
# train = ['you', 'idle', 'get', 'you']
# vocab = ['you', 'idle', 'get', 'you']

# train, vocab = 

from nltk.lm import MLE
lm = MLE(2)
print(len(lm.vocab))
lm.fit(train, vocab)

# print(model['you']['idle'])
# print(model['get']['you'])
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 8
#       4
#       5 from nltk.lm import MLE
#       6 lm = MLE(2)
#       7 print(len(lm.vocab))
# ----> 8 lm.fit(train, vocab)
#       9
#      10 print(model['you']['idle'])
#      11 print(model['get']['you'])
#
# File ~/Documents/Development/classes/lin_6932_all_computational_models_are_wrong/.venv/lib/python3.12/site-packages/nltk/lm/api.py:117, in LanguageModel.fit(self, text, vocabulary_text)
#     113         raise ValueError(
#     114             "Cannot fit without a vocabulary or text to create it from."
#     115         )
#     116     self.vocab.update(vocabulary_text)
# --> 117 self.counts.update(self.vocab.lookup(sent) for sent in text)
#
# ...

# %% [markdown]
# Now calculate the bigram probability of every bigram in variable ```model```

# %%
### Insert your code here
lm = MLE(2)

for sentence in gutenberg.sents('shakespeare-caesar.txt'): #for all sentences
    #words should be lowercase (lower()), remove all punctuation (isalpha())
    words = [word.lower() for word in sentence if word.isalpha()]

    for w1, w2 in bigrams(words, pad_right=True, pad_left=True): #now we count bigrams according to their occurrence
        model[w1][w2] += 1

        print(len(lm.vocab))
        lm.fit(model, vocab)
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 13
#       9     for w1, w2 in bigrams(words, pad_right=True, pad_left=True): #now we count bigrams according to their occurrence
#      10         model[w1][w2] += 1
#      11
#      12         print(len(lm.vocab))
# ---> 13         lm.fit(model, vocab)
#
# File ~/Documents/Development/classes/lin_6932_all_computational_models_are_wrong/.venv/lib/python3.12/site-packages/nltk/lm/api.py:117, in LanguageModel.fit(self, text, vocabulary_text)
#     113         raise ValueError(
#     114             "Cannot fit without a vocabulary or text to create it from."
#     115         )
#     116     self.vocab.update(vocabulary_text)
# --> 117 self.counts.update(self.vocab.lookup(sent) for sent in text)
#
# ...
